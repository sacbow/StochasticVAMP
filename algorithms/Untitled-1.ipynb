# %%
#import modules
import numpy as np
from numpy import linalg as LA
from numpy.fft import fft2, ifft2, fftshift
from matplotlib import pyplot as plt
from matplotlib.pyplot import rc
rc('text', usetex=True)
import cv2

# %%
#load image
image = cv2.imread('../data/cameraman.png', 0) #256*256 pixels
x = image.astype('float')/256 # x is [0,1]-valued

# %%
plt.axis("off")
plt.imshow(np.abs(x + np.random.normal(loc = 0, scale = 0.1, size = (256,256))), cmap = "gray")
